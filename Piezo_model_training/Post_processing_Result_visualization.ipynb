# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib.ticker import MaxNLocator
from matplotlib.legend_handler import HandlerPathCollection
# Data
load1 = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]
disp1 = [0.15, 0.29, 0.44, 0.58, 0.73]
voltage1 = [0.47, 0.94, 1.4, 1.9, 2.3]

load2 = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]
disp2 = [0.19, 0.39, 0.58, 0.77, 0.97]
voltage2 = [0.78, 1.6, 2.3, 3.1, 3.9]

load3 = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]
disp3 = [0.19, 0.39, 0.58, 0.77, 0.97]
voltage3 = [1.6, 3.1, 4.7, 6.2, 7.8]

load4 = [1e-5, 2e-5, 3e-5, 4e-5, 5e-5]
disp4 = [0.19, 0.39, 0.58, 0.77, 0.97]
voltage4 = [0.64, 1.3, 1.9, 3.0, 4.7]

# Combine the data points for each case
loads = [load1, load2, load3, load4]
disps = [disp1, disp2, disp3, disp4]
voltages = [voltage1, voltage2, voltage3, voltage4]

# Create the figure and axes
fig = plt.figure(figsize=(7, 8))
ax = fig.add_subplot(111, projection='3d')

# Plot the data points with lines
marker = ['o', 'x', 'd', 's']
linestyle = ['-', '-', '-', '-']
color=['red', 'k', 'k', 'k']
for disp, load, voltage, m, ls, color in zip(disps, loads, voltages, marker, linestyle, color):
    ax.plot(disp, load, voltage, marker=m, markersize=5, linestyle=ls, linewidth=1.5, c=color, alpha=0.95)

# Set labels and title
ax.set_xlabel('\n '+r'$\mathbf{\delta_z, \ \mu}$m', fontsize=16, fontweight='bold', color='indigo')
ax.set_ylabel(r'F'+'$\mathbf{_{z, } \ x 10^{-5}\ N/m^2} $', fontsize=16, fontweight='bold', color='indigo',rotation=60)
ax.set_zlabel('\n'+r'$ \mathbf{\lambda, }$ V', fontsize=16, fontweight='bold', color='indigo')
ax.set_title('3D Line Plot', fontsize=16, fontweight='bold')

# Remove grid lines
ax.grid(False)

# Adjust the plot limits for better visibility
ax.set_ylim([1e-5, 5e-5])
ax.set_xlim([0.1, 1.0])
ax.set_zlim([0.5, 8])

ax.xaxis.set_major_locator(MaxNLocator(5))
ax.yaxis.set_major_locator(MaxNLocator(5))
ax.zaxis.set_major_locator(MaxNLocator(5))

# Set tick parameters
ax.tick_params(axis='x', which='major', labelsize=16, width=4, length=20, direction='in', pad=1)
ax.tick_params(axis='y', which='major', labelsize=16, width=4, length=10, direction='in', pad=0.1)
ax.tick_params(axis='z', which='major', labelsize=16, width=4, length=10, direction='in', pad=5)

# Make tick line labels bold
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_weight('bold')

for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_weight('bold')

for tick in ax.zaxis.get_major_ticks():
    tick.label1.set_weight('bold')

# Adjust tick line length and thickness
ax.xaxis._axinfo['tick']['inward_factor'] = 0.25
ax.xaxis._axinfo['tick']['outward_factor'] = 0.25
ax.yaxis._axinfo['tick']['inward_factor'] = 0.05
ax.yaxis._axinfo['tick']['outward_factor'] = 0.3
ax.zaxis._axinfo['tick']['inward_factor'] = 0.1
ax.zaxis._axinfo['tick']['outward_factor'] = 0.3

legend_labels = ['Pure AlN, '+r'$\mathbf{e_o}$',  'Doped alloy, e*', 'Doped and rotated, '+r"$\mathbf{e_1}$*'", 'Doped and rotated, '+r"$\mathbf{e_2}$*'" , ]
legend = ax.legend(legend_labels, loc='upper left',  bbox_to_anchor=(-0.01, 0.85), fontsize=14, frameon=False)
# legend.get_frame().set_visible(False)

# Modify the marker size in the legend handles
for handle in legend.legendHandles:
    handle.set_markersize(10)

# Make legend font bold and change font color
for text in legend.get_texts():
    text.set_weight('bold')
    text.set_color('red')  # Set font color to red

# Set background color
ax.set_facecolor('None')

# Rotate the axis for better visualization
ax.view_init(elev=20, azim=-75)

plt.savefig('plots//fem.png', dpi=1200)
# Show the plot
plt.show()
# Out:
# /tmp/ipykernel_14178/3241561696.py:85: MatplotlibDeprecationWarning: The legendHandles attribute was deprecated in Matplotlib 3.7 and will be removed two minor releases later. Use legend_handles instead.
#   for handle in legend.legendHandles:

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator

# Data
load1 = [1, 2, 3, 4, 5]
power1 = [8.73, 34.92, 77.47, 142.69, 209.10]

load2 = [1, 2, 3, 4, 5]
power2 = [20.82, 87.63, 181.09, 328.97, 520.67]

load3 = [1, 2, 3, 4, 5]
power3 = [87.63, 328.97, 756.19, 1315.90, 2082.71]

load4 = [1, 2, 3, 4, 5]
power4 = [14.02, 57.85, 123.58, 308.09, 756.19]

# Plot the data
plt.figure(figsize=(4, 6))

plt.plot(load1, power1, marker='o', label='Pure AlN, '+r'$\mathbf{e_o}$', color='red', markersize=8, linewidth=2)
plt.plot(load2, power2, marker='x', label='Doped alloy,' +r'$\mathbf{e}$*', color='k', markersize=8, linewidth=2)
plt.plot(load3, power3, marker='d', label='Doped and rotated, '+r"$\mathbf{e_1}$*'", color='k', markersize=8, linewidth=2)
plt.plot(load4, power4, marker='s', label='Doped and rotated, '+r"$\mathbf{e_2}$*'", color='k', markersize=8, linewidth=2)

# Set labels and title
plt.xlabel('F' + r'$\mathbf{_{z, } \ x 10^{-5} \ N/m^2}$', fontsize=18, fontweight='bold', color='indigo')
plt.ylabel('Power (P), ' + r'$\mathbf{\mu W}$', fontsize=18, fontweight='bold', color='indigo')
plt.title(' ', fontsize=16, fontweight='bold')

# Customize other settings as needed
plt.grid(False)
# plt.legend(fontsize=13)

plt.gca().xaxis.set_major_locator(MaxNLocator(5))
plt.gca().yaxis.set_major_locator(MaxNLocator(5))

# Adjust tick line length and thickness
# Adjust tick line length and thickness
plt.tick_params(axis='both', which='major',direction='in', labelsize=16, length=6, width=2)


# Set tick parameters
plt.tick_params(axis='both', which='major', labelsize=16)

# Make tick line labels bold
for tick in plt.gca().xaxis.get_major_ticks():
    tick.label1.set_weight('bold')

for tick in plt.gca().yaxis.get_major_ticks():
    tick.label1.set_weight('bold')

    plt.tight_layout()
plt.savefig('plots/power_vs_load.png', dpi=300)
plt.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_o.shape[1])
y = np.linspace(0, 2, num=e_o.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_o))

# Customize the surface plot
fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        )
    )
)

# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_o.shape[1])
y = np.linspace(0, 2, num=e_o.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_o, colorscale='plasma', cmin=-9, cmax=9))

# Customize the surface plot
fig.update_layout(
    title='Surface Plot',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        ),
        zaxis=dict(tickfont=dict(size=24)),
    )
)

# Customize the layout
fig.update_layout(
    scene=dict(
        xaxis_visible=False,
        yaxis_visible=False,
        zaxis_nticks=3, 
#         zaxis_visible=False,
        aspectmode='data',
        bgcolor='rgba(0,0,0,0)'
    )
)


# Show the plot
fig.show()

# %%
e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])


# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_star.shape[1])
y = np.linspace(0, 2, num=e_star.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_star, colorscale='plasma', cmin=-9, cmax=9))

# Customize the surface plot
fig.update_layout(
    title='Surface Plot',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        ),
        zaxis=dict(tickfont=dict(size=24)),
    )
)

# Customize the layout
fig.update_layout(
    scene=dict(
        xaxis_visible=False,
        yaxis_visible=False,
        zaxis_nticks=3, 
#         zaxis_visible=False,
        aspectmode='data',
        bgcolor='rgba(0,0,0,0)'
    )
)


# Show the plot
fig.show()

# %%
e_1_star = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])


# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_1_star.shape[1])
y = np.linspace(0, 2, num=e_1_star.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_1_star, colorscale='plasma', cmin=-9, cmax=9))




# Customize the surface plot
fig.update_layout(
    title='Surface Plot',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        ),
        zaxis=dict(tickfont=dict(size=24)),
    )
)




# Customize the colorscale bar
fig.update_layout(font=dict[size = 24]
   
)



# Customize the layout
fig.update_layout(
    scene=dict(
        xaxis_visible=False,
        yaxis_visible=False,
        zaxis_nticks=5, 
#         zaxis_visible=False,
        aspectmode='data',
        bgcolor='rgba(0,0,0,0)'
    )
)


# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

e_1_star = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_1_star.shape[1])
y = np.linspace(0, 2, num=e_1_star.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_1_star, colorscale='plasma', cmin=-9, cmax=9))

# Customize the surface plot
fig.update_layout(
    title='Surface Plot',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        ),
        zaxis=dict(tickfont=dict(size=24)),
    ),
    
    
    coloraxis_colorbar=dict(
    title="Z",
    thicknessmode="pixels", thickness=50,
    lenmode="pixels", len=100,
    yanchor="middle", y=0.5,
    tickfont=dict(size=30),
)
)


# Create a colorbar
colorbar = go.ColorBar(
    title='Colorbar Title',
    tickmode='array',
    tickvals=[-8, -4, 0, 4, 8],
    ticktext=['-8', '-4', '0', '4', '8'],
    tickfont=dict(size=14)  # Adjust the font size here
)
# Customize the layout
fig.update_layout(
    scene=dict(
        xaxis_visible=False,
        yaxis_visible=False,
        zaxis_nticks=5,
        aspectmode='data',
        bgcolor='rgba(0,0,0,0)'
    )
)

# Show the plot
fig.show()

# %%
e_2_star = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_2_star.shape[1])
y = np.linspace(0, 2, num=e_2_star.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_2_star, colorscale='plasma', cmin=-9, cmax=9))

# Customize the surface plot
fig.update_layout(
    title='Surface Plot',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        ),
        zaxis=dict(tickfont=dict(size=24)),
    )
)

# Customize the layout
fig.update_layout(
    scene=dict(
        xaxis_visible=False,
        yaxis_visible=False,
        zaxis_nticks=3, 
#         zaxis_visible=False,
        aspectmode='data',
        bgcolor='rgba(0,0,0,0)'
    )
)


# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

e_1_star = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_1_star.shape[1])
y = np.linspace(0, 2, num=e_1_star.shape[0])
x, y = np.meshgrid(x, y)

# Create the surface plot
fig = go.Figure(data=go.Surface(x=x, y=y, z=e_1_star, colorscale='plasma', cmin=-8, cmax=8))

# Customize the surface plot
fig.update_layout(
    title='Surface Plot',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        ),
        zaxis=dict(tickfont=dict(size=24)),
    )
)



# Customize the layout and adjust figure size
fig.update_layout(
    scene=dict(
        xaxis_visible=False,
        yaxis_visible=False,
        zaxis_nticks=5,
        aspectmode='data',
        bgcolor='rgba(0,0,0,0)'
    ),
    width=1200,  # Adjust the figure width
    height=1000  # Adjust the figure height
)



# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])

e_1_star = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

e_2_star = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_o.shape[1])
y = np.linspace(0, 2, num=e_o.shape[0])
x, y = np.meshgrid(x, y)

# Create separate traces for each layer
trace_e_o = go.Surface(x=x, y=y, z=e_o, showscale=False, colorscale='Viridis')
trace_e_star = go.Surface(x=x, y=y, z=e_star, showscale=False, colorscale='Viridis')
trace_e_1_star = go.Surface(x=x, y=y, z=e_1_star, showscale=False, colorscale='Viridis')
trace_e_2_star = go.Surface(x=x, y=y, z=e_2_star, showscale=False, colorscale='Viridis')

# Create the figure
fig = go.Figure(data=[trace_e_o, trace_e_star, trace_e_1_star, trace_e_2_star])

# Customize the layout
fig.update_layout(
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        )
    )
)

# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])

e_1_star = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

e_2_star = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Create x, y coordinates for the surface
x = np.linspace(0, 5, num=e_o.shape[1])
y = np.linspace(0, 2, num=e_o.shape[0])
x, y = np.meshgrid(x, y)

# Create separate plots for each layer
fig = make_subplots(rows=2, cols=2, subplot_titles=['e_o', 'e_star', 'e_1_star', 'e_2_star'])

fig.add_trace(
    go.Surface(x=x, y=y, z=e_o, showscale=False, colorscale='Viridis', cmin=np.min([e_o, e_star, e_1_star, e_2_star]), cmax=np.max([e_o, e_star, e_1_star, e_2_star])),
    row=1, col=1
)

fig.add_trace(
    go.Surface(x=x, y=y, z=e_star, showscale=False, colorscale='Viridis', cmin=np.min([e_o, e_star, e_1_star, e_2_star]), cmax=np.max([e_o, e_star, e_1_star, e_2_star])),
    row=1, col=2
)

fig.add_trace(
    go.Surface(x=x, y=y, z=e_1_star, showscale=False, colorscale='Viridis', cmin=np.min([e_o, e_star, e_1_star, e_2_star]), cmax=np.max([e_o, e_star, e_1_star, e_2_star])),
    row=2, col=1
)

fig.add_trace(
    go.Surface(x=x, y=y, z=e_2_star, showscale=False, colorscale='Viridis', cmin=np.min([e_o, e_star, e_1_star, e_2_star]), cmax=np.max([e_o, e_star, e_1_star, e_2_star])),
    row=2, col=2
)

# Customize the layout
fig.update_layout(
    title='Separate Matrix Plots',
    scene=dict(
        xaxis_title='X',
        yaxis_title='Y',
        zaxis_title='Z',
        camera=dict(
            eye=dict(x=1.5, y=1.5, z=0.6)
        )
    )
)

# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])

e_star_1 = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

e_star_2 = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Create the plot
fig = go.Figure()

# Scatter plot for e_o
X, Y = np.meshgrid(np.arange(6), np.arange(3))
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_o.flatten(),
    mode='markers',
    marker=dict(symbol='circle', size=4, color='red'),
    name='e_o'
))

# Scatter plot for e_star
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star.flatten(),
    mode='markers',
    marker=dict(symbol='square', size=4, color='green'),
    name='e_star'
))

# Scatter plot for e_star_1
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_1.flatten(),
    mode='markers',
    marker=dict(symbol='circle', size=4, color='blue'),
    name='e_star_1'
))

# Scatter plot for e_star_2
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_2.flatten(),
    mode='markers',
    marker=dict(symbol='x', size=4, color='purple'),
    name='e_star_2'
))

# Vertical lines for the length of values
line_length = np.abs(e_o.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='red', width=2),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='green', width=2),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star_1.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='blue', width=2),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star_2.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='purple', width=2),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

# Set layout
fig.update_layout(
    scene=dict(
        xaxis_title='Column',
        yaxis_title='Row',
        zaxis_title='Value',
    ),
    legend=dict(
        x=0.8,
        y=0.9,
        bgcolor='rgba(255, 255, 255, 0.7)',
        bordercolor='rgba(0, 0, 0, 0.7)',
        borderwidth=1,
    )
)

# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])

e_star_1 = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

e_star_2 = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Create the plot
fig = go.Figure()

# Scatter plot for e_o
X, Y = np.meshgrid(np.arange(6), np.arange(3))
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_o.flatten(),
    mode='markers',
    marker=dict(symbol='circle', size=4, color='red'),
    name='e_o'
))

# Scatter plot for e_star
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star.flatten(),
    mode='markers',
    marker=dict(symbol='square', size=4, color='green'),
    name='e_star'
))

# Scatter plot for e_star_1
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_1.flatten(),
    mode='markers',
    marker=dict(symbol='diamond', size=4, color='blue'),
    name='e_star_1'
))

# Scatter plot for e_star_2
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_2.flatten(),
    mode='markers',
    marker=dict(symbol='x', size=4, color='purple'),
    name='e_star_2'
))

# Vertical lines for the length of values
line_length = np.abs(e_o.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='red', width=5),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='green', width=5),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star_1.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='blue', width=5),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star_2.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='purple', width=5),
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

# Create the XY plane at z=0
plane = go.Surface(
    x=X,
    y=Y,
    z=np.zeros_like(X),
    surfacecolor=np.zeros_like(X),
    colorscale=[[0, 'rgba(0, 0, 0, 0.2)'], [1, 'rgba(0, 0, 0, 0.2)']],
    showscale=False,
    hoverinfo='skip'
)
fig.add_trace(plane)

# Set layout
fig.update_layout(
    scene=dict(
        xaxis_title='Column',
        yaxis_title='Row',
        zaxis_title='Value',
        xaxis=dict(showbackground=False, visible=True),
        yaxis=dict(showbackground=False, visible=True),
        zaxis=dict(showbackground=False, visible=True, range=[-9, 9]),
        camera=dict(
            eye=dict(x=-1.5, y=-1.5, z=0.5),
            up=dict(x=0, y=0, z=1),
            center=dict(x=0, y=0, z=0)
        )
    ),
    showlegend=False,
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)'
)

# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])

e_star_1 = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

e_star_2 = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Create the plot
fig = go.Figure()

# Scatter plot for e_o
X, Y = np.meshgrid(np.arange(6), np.arange(3))
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_o.flatten(),
    mode='markers',
    marker=dict(symbol='circle', size=4, color='black'),  # Set marker color to black
    name='e_o'
))

# Scatter plot for e_star
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star.flatten(),
    mode='markers',
    marker=dict(symbol='square', size=4, color='black'),  # Set marker color to black
    name='e_star'
))

# Scatter plot for e_star_1
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_1.flatten(),
    mode='markers',
    marker=dict(symbol='diamond', size=4, color='black'),  # Set marker color to black
    name='e_star_1'
))

# Scatter plot for e_star_2
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_2.flatten(),
    mode='markers',
    marker=dict(symbol='x', size=4, color='black'),  # Set marker color to black
    name='e_star_2'
))

# Vertical lines for the length of values
line_length = np.abs(e_o.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='blue' if value >= 0 else 'red', width=5),  # Color based on positive/negative value
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='blue' if value >= 0 else 'red', width=5),  # Color based on positive/negative value
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star_1.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='blue' if value >= 0 else 'red', width=5),  # Color based on positive/negative value
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

line_length = np.abs(e_star_2.flatten())
line_segments = [
    go.Scatter3d(
        x=[x, x],
        y=[y, y],
        z=[0, value],
        mode='lines',
        line=dict(color='blue' if value >= 0 else 'red', width=5),  # Color based on positive/negative value
        hoverinfo='skip'
    ) for x, y, value in zip(X.flatten(), Y.flatten(), line_length)
]
fig.add_traces(line_segments)

# Create the XY plane at z=0
plane = go.Surface(
    x=X,
    y=Y,
    z=np.zeros_like(X),
    surfacecolor=np.zeros_like(X),
    colorscale=[[0, 'rgba(0, 0, 0, 0.2)'], [1, 'rgba(0, 0, 0, 0.2)']],
    showscale=False,
    hoverinfo='skip'
)
fig.add_trace(plane)

# Set layout
fig.update_layout(
    scene=dict(
        xaxis_title='Column',
        yaxis_title='Row',
        zaxis_title='Value',
        xaxis=dict(showbackground=False, visible=True),
        yaxis=dict(showbackground=False, visible=True),
        zaxis=dict(showbackground=False, visible=True, range=[-6, 8]),  # Set z-axis range from -6 to 8
        camera=dict(
            eye=dict(x=-1.5, y=-1.5, z=1),  # Adjust camera position for better view
            up=dict(x=0, y=0, z=1),
            center=dict(x=0, y=0, z=0)
        )
    ),
    showlegend=False,
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)'
)

# Show the plot
fig.show()

# %%
import numpy as np
import plotly.graph_objects as go

# Define the matrices
e_o = np.array([[0, 0, 0, 0, -0.2893, 0],
                [0, 0, 0, -0.2893, 0, 0],
                [-0.5801, -0.5801, 1.461, 0, 0, 0]])

e_star = np.array([[0, 0, 0, 0, 0.2283, 0],
                   [0, 0, 0, 0.2283, 0, 0],
                   [0.0943, 0.0943, 4.363, 0, 0, 0]])

e_star_1 = np.array([[0, 0.08, 0, -0.0808, 0.459, -0.4554],
                     [-0.1882, -4.563, -4.3232, 8.7947, -0.0807, 0.146],
                     [0.1899, 4.3775, 4.3636, -8.6464, 0, -0.0667]])

e_star_2 = np.array([[1.1354, 0.947, 0.9856, -1.825, -2.005, 1.9339],
                     [0.9564, 1.098, 0.9799, -1.9783, -1.8336, 1.93],
                     [-0.9946, -0.9778, -1.0156, 1.9799, 2.0, -1.838]])

# Calculate the range of all the data points
data_min = np.min([e_o, e_star, e_star_1, e_star_2])
data_max = np.max([e_o, e_star, e_star_1, e_star_2])
data_range = data_max - data_min

# Create the plot
fig = go.Figure()

# Scatter plot for e_o
X, Y = np.meshgrid(np.arange(6), np.arange(3))
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_o.flatten(),
    mode='markers',
    marker=dict(symbol='circle', size=3, color='black'),
    name='e_o'
))

# Scatter plot for e_star
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star.flatten(),
    mode='markers',
    marker=dict(symbol='x', size=3, color='black'),
    name='e_star'
))

# Scatter plot for e_star_1
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_1.flatten(),
    mode='markers',
    marker=dict(symbol='diamond', size=3, color='black'),
    name='e_star_1'
))

# Scatter plot for e_star_2
fig.add_trace(go.Scatter3d(
    x=X.flatten(),
    y=Y.flatten(),
    z=e_star_2.flatten(),
    mode='markers',
    marker=dict(symbol='square', size=2, color='black'),
    name='e_star_2'
))



# Create the XY plane at z=0
plane = go.Surface(
    x=X,
    y=Y,
    z=np.zeros_like(X),
    surfacecolor=np.zeros_like(X),
    colorscale=[[0, 'rgba(0, 1, 0, 0.2)'], [1, 'rgba(0, 1, 0, 0.2)']],
    showscale=False,
    hoverinfo='skip'
)
fig.add_trace(plane)





# Set layout
fig.update_layout(
    width=600,  # Set the width of the plot (in pixels)
    height=500,
    scene=dict(
        xaxis_title='Column',
        yaxis_title='Row',
        zaxis_title='Value',
        xaxis=dict(showbackground=False, visible=True),
        yaxis=dict(showbackground=False, visible=True),
        zaxis=dict(showbackground=False, visible=True, range=[-9,9],dtick=4),  # Adjust the range based on your preference
        
        camera=dict(
            eye=dict(x=-1.5, y=-1.0, z=0.5),
            up=dict(x=0, y=0, z=1),
            center=dict(x=0, y=0, z=0)
        )
    ),
    showlegend=True,  # Enable legend
    legend=dict(font=dict(size=14, color='black'), itemwidth=40),  # Set legend font size and marker size
    plot_bgcolor='rgba(0, 0, 0, 0)',
    paper_bgcolor='rgba(0, 0, 0, 0)'
)


for trace in fig.data:
    if isinstance(trace, go.Scatter3d):
        marker_color = ['rgba(0, 0, 0, 0.7)' if val >= 0 else 'rgba(0, 0, 255, 0.7)' for val in trace.z]
        trace.marker.color = marker_color

# Update tick label font size and style
fig.update_layout(
    scene=dict(
        xaxis=dict(tickfont=dict(size=1, family='Arial', color='black')),
        yaxis=dict(tickfont=dict(size=1, family='Arial', color='black')),
        zaxis=dict(tickfont=dict(size=16, family='Arial', color='black')),
    )
)
        
        
# Show the plot
fig.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tck
from matplotlib.ticker import MaxNLocator

# Data
labels = ['AlN', 'd-AlN', 'd1-AlN', 'd2-AlN']
voltage = [6.1, 9.8, 27, 9.4]
disp = [0.18, 0.21, 0.24, 0.24]

# Create scatter plot with customizations
plt.scatter(disp, voltage, color='r', marker='o', s=100)

# Add labels to data points
for i, label in enumerate(labels):
    plt.annotate(label, (disp[i], voltage[i]), textcoords="offset points", xytext=(0,-20), ha='center', fontsize=16, fontweight='bold')

# Set plot title and axis labels
plt.title("Displacement vs. Voltage", fontsize=14, fontweight='bold')
plt.xlabel("Deformation, "+r"$\mathbf{\mu m}$", fontsize=18, fontweight='bold', color='indigo')
plt.ylabel("Potential "+r"$\mathbf{(\lambda), \ V}$", fontsize=18, fontweight='bold', color='indigo')

# Set plot limits and grid
plt.xlim(0.17, 0.25)
plt.ylim(2, 29)
plt.grid(True, which='major', linestyle='-', alpha=0.5)
plt.grid(True, axis='y', which='minor', linestyle='-', alpha=0.1)

# Set the minor locator for the x-axis
ax = plt.gca()


# Set minor ticks for the x-axis
x_major_ticks = np.arange(0.18, 0.25, 0.02)
plt.xticks(x_major_ticks, fontsize=18, fontweight='bold')

# Add minor tick lines
ax.xaxis.set_minor_locator(tck.AutoMinorLocator(2))
ax.yaxis.set_minor_locator(tck.AutoMinorLocator(2))

# Increase tick length and width
plt.tick_params(axis='both', which='major', width=2, length=8)
plt.tick_params(axis='both', which='minor', width=1.2, length=4)

# Set font properties for tick labels
plt.yticks(fontsize=18, fontweight='bold')

# Add a background color to the plot
plt.gca().set_facecolor('white')

# Adjust the figure size
plt.figure(figsize=(8, 6))

# Adjust the spacing around the plot
plt.tight_layout()

plt.savefig('plots/fem_ortho.png', dpi=800)

# Display the plot
plt.show()

# %%
# Supplementary

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.ticker as tck
from matplotlib.ticker import MaxNLocator

# Data
labels = ['AlN', 'd-AlN', 'd1-AlN', 'd2-AlN']
voltage = [2.2, 3.1, 7.6, 2.8]
# disp = [0.78, 0.88, 0.88, 0.88]
disp = [9.81, 21.42, 90.13, 14.42] # this is power

# Create scatter plot with customizations
plt.scatter(disp, voltage, color='r', marker='o', s=100)

# # Add labels to data points
# for i, label in enumerate(labels):
#     plt.annotate(label, (disp[i]+5, voltage[i]+0.5), textcoords="offset points", xytext=(0,-20), ha='center', fontsize=16, fontweight='bold')

# Set plot title and axis labels
plt.title(" ", fontsize=14, fontweight='bold')
plt.xlabel("Power (P), "+r"$\mathbf{\mu W}$", fontsize=18, fontweight='bold', color='indigo')
plt.ylabel("Potential "+r"$\mathbf{(\lambda), \ V}$", fontsize=18, fontweight='bold', color='indigo')

# Set plot limits and grid
# plt.xlim(0.17, 0.25)
plt.ylim(1, 7.9)
plt.grid(True, which='major', linestyle='-', alpha=0.5)
plt.grid(True, axis='y', which='minor', linestyle='-', alpha=0.1)

# Set the minor locator for the x-axis
ax = plt.gca()


# Set minor ticks for the x-axis
x_major_ticks = np.arange(0, 100, 25)
plt.xticks(x_major_ticks, fontsize=18, fontweight='bold')

# Add minor tick lines
ax.xaxis.set_minor_locator(tck.AutoMinorLocator(2))
ax.yaxis.set_minor_locator(tck.AutoMinorLocator(2))

# Increase tick length and width
plt.tick_params(axis='both', which='major', width=2, length=8)
plt.tick_params(axis='both', which='minor', width=1.2, length=4)

# Set font properties for tick labels
plt.yticks(fontsize=18, fontweight='bold')

# Add a background color to the plot
plt.gca().set_facecolor('white')

# Adjust the figure size
# plt.figure(figsize=(8, 6))

# Adjust the spacing around the plot
plt.tight_layout()

plt.savefig('plots/fem_ortho.png', dpi=800)

# Display the plot
plt.show()
